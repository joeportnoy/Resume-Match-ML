# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arshkon/linkedin-job-postings")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/joeportnoy/.cache/kagglehub/datasets/arshkon/linkedin-job-postings/versions/13

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('../resources/postings.csv')

# Show the column names
print(df.columns)
# Out:
# Index(['job_id', 'company_name', 'title', 'description', 'max_salary',
#        'pay_period', 'location', 'company_id', 'views', 'med_salary',
#        'min_salary', 'formatted_work_type', 'applies', 'original_listed_time',
#        'remote_allowed', 'job_posting_url', 'application_url',
#        'application_type', 'expiry', 'closed_time',
#        'formatted_experience_level', 'skills_desc', 'listed_time',
#        'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type', 'normalized_salary', 'zip_code', 'fips'],
#       dtype='object')

# %%
import re

# Example job titles you're searching for
job_titles = [
    "data analyst",
    "business intelligence analyst",
    "marketing analyst",
    "junior data scientist",
    "data analytics intern"
]

# Compile regex pattern (escaped, joined with OR "|")
pattern = "|".join([re.escape(title) for title in job_titles])

# Filter the DataFrame
filtered_df = df[
    df["title"].str.contains(pattern, case=False, na=False)
]

# Optional: Reset index
filtered_df.reset_index(drop=True, inplace=True)

filtered_df
# Out:
#          job_id         company_name  \
# 0    3813645405           Tenazx Inc
# 1    3872787865  Radiant Systems Inc
# 2    3884432522            MCubeSoft
# 3    3884434978              Outlier
# 4    3884435156       Insight Global
# ..          ...                  ...
# 472  3906240634      Reliance Matrix
# 473  3906246968         Cisco Meraki
# 474  3906249532         orangepeople
# 475  3906251726      CHRISTUS Health
# 476  3906254796             Huntress
#
#                                                  title  \
# 0                                         Data Analyst
# 1                               eCommerce Data Analyst
# 2              Wealth Management Business Data Analyst
# 3    Senior Data Analyst - AI Training (Remote, Con...
# 4                        Business Intelligence Analyst
# ..                                                 ...
# 472                      Business Intelligence Analyst
# 473                                       Data Analyst
# 474                                       Data Analyst
# 475              Data Analyst II - Staff Credentialing
# 476                                Senior Data Analyst
#
#                                            description  max_salary pay_period  \
# 0    Job Title: Data AnalystDuration: ContractLocat...         NaN        NaN
# 1    Job Description: JOB SUMMARY:Responsible for c...         NaN        NaN
# 2    Job Title: BUSINESS DATA ANALYST Location: Aus...         NaN        NaN
# 3    Job Type: Contract\n\nWe don’t sponsor work vi...         NaN     HOURLY
# 4    Title: BI AnalystLocation: Fishers, IN Must Ha...     67000.0     YEARLY
# ..                                                 ...         ...        ...
# 472  Job Responsibilities And Requirements\n\nThe B...         NaN        NaN
# 473  Who We Are:\n\nOur employees fuel the magic of...         NaN        NaN
# 474  We are looking for a passionate certified data...        89.0     HOURLY
# 475  Description\n\nSummary:\n\nThis position is re...         NaN        NaN
# 476  Reports to: Senior Director of Finance\n\nLoca...    140000.0     YEARLY
#
#              location  company_id  views  med_salary  ...  skills_desc  \
# 0          Queens, NY  82537206.0    4.0         NaN  ...          NaN
# 1       United States   3342169.0  102.0         NaN  ...          NaN
# 2       Charlotte, NC  74604183.0    8.0         NaN  ...          NaN
# 3       United States  92583550.0  258.0        55.0  ...          NaN
# 4         Fishers, IN     11056.0   83.0         NaN  ...          NaN
# ..                ...         ...    ...         ...  ...          ...
# 472  Philadelphia, PA  92709511.0    3.0         NaN  ...          NaN
# 473     United States     92950.0    4.0         NaN  ...          NaN
# 474       Orlando, FL   2708565.0    NaN         NaN  ...          NaN
# 475        Irving, TX     10769.0    4.0         NaN  ...          NaN
# 476     United States  10172550.0    3.0         NaN  ...          NaN
#
#       listed_time              posting_domain  sponsored  work_type currency  \
# 0    1.713465e+12                         NaN          0   CONTRACT      NaN
# 1    1.713278e+12                         NaN          0   CONTRACT      NaN
# 2    1.712346e+12                         NaN          0  FULL_TIME      NaN
# 3    1.712350e+12        boards.greenhouse.io          0   CONTRACT      USD
# 4    1.712347e+12                         NaN          0  FULL_TIME      USD
# ..            ...                         ...        ...        ...      ...
# 472  1.713565e+12  rsli.wd5.myworkdayjobs.com          0  FULL_TIME      NaN
# 473  1.713566e+12            meraki.cisco.com          0  FULL_TIME      NaN
# 474  1.713565e+12                         NaN          0   CONTRACT      USD
# 475  1.713567e+12  careers.christushealth.org          0  FULL_TIME      NaN
# 476  1.713568e+12        boards.greenhouse.io          0  FULL_TIME      USD
#
#     compensation_type normalized_salary  zip_code     fips
# 0                 NaN               NaN   11427.0  36081.0
# 1                 NaN               NaN       NaN      NaN
# 2                 NaN               NaN   28202.0  37119.0
# 3         BASE_SALARY          114400.0       NaN      NaN
# 4         BASE_SALARY           63500.0   46037.0      NaN
# ..                ...               ...       ...      ...
# 472               NaN               NaN   19102.0  42101.0
# 473               NaN               NaN       NaN      NaN
# 474       BASE_SALARY          179920.0   32801.0  12095.0
# 475               NaN               NaN   75038.0  48113.0
# 476       BASE_SALARY          130000.0       NaN      NaN
#
# [477 rows x 31 columns]

# %%
# Keep only useful columns for the ML model
useful_columns = [
    "title", "description", "skills_desc",
    "work_type", "location", "company_name"
]

df_clean = filtered_df[useful_columns].copy()

# %%
# Drop missing or empty descriptions
df_clean.dropna(subset=["description"], inplace=True)
df_clean = df_clean[df_clean["description"].str.strip() != ""]

# %%
#Fill data with unknown for skills
df_clean["skills_desc"] = df_clean["skills_desc"].fillna("")

# Optionally fill location or work_type
df_clean["location"] = df_clean["location"].fillna("Unknown")
df_clean["work_type"] = df_clean["work_type"].fillna("Unknown")

# %%
# Normalize text for NLP
for col in ["title", "description", "skills_desc", "location", "work_type", "company_name"]:
    df_clean[col] = df_clean[col].astype(str).str.strip().str.lower()

# %%
# Combine into single text field for vectorizing
df_clean["job_text"] = (
    df_clean["title"] + " " +
    df_clean["skills_desc"] + " " +
    df_clean["description"]
)

# %%
# Remove duplicates
df_clean.drop_duplicates(subset=["job_text"], inplace=True)

# %%
df_clean.to_csv("cleaned_jd_data.csv", index=False)
